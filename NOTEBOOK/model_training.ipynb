# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df= pd.read_csv('../DATA/student-mat-cleaned.csv')

# %%
# DIVIDING FEATURES INTO DEPENDENT AND INDIPENDENT

X = df[['G2', 'Dalc', 'absences', 'failures', 'internet']]
Y= df['G3']

# %%
# TRAIN TEST SPLITTING
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# PERFORMING STANDARDIZATION

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
sns.scatterplot(x=X_train_scaled[:,0],y=Y_train, color='blue', label='Train Data')
# Out:
# <Axes: ylabel='G3'>

# %%
regression = LinearRegression()
regression.fit(X_train_scaled, Y_train)
# Out:
# LinearRegression()

# %%
Y_pridicted = regression.predict(X_test_scaled)

# %%
r2 = r2_score(Y_test, Y_pridicted)
mse = mean_squared_error(Y_test, Y_pridicted)

print(f"R^2 Score: {r2}")
print(f"Mean Squared Error: {mse}")
# Out:
# R^2 Score: 0.7768402025570351
# Mean Squared Error: 4.575902194900032

# %%
sns.scatterplot(x=Y_test, y=Y_pridicted)
# Out:
# <Axes: xlabel='G3'>

# %%
print(Y_test[:10])
# Out:
# 78     10
# 371    12
# 248     5
# 55     10
# 390     9
# 223    13
# 42     18
# 234     6
# 316     0
# 116    14
# Name: G3, dtype: int64

# %%
print(Y_pridicted[:10])
# Out:
# [ 5.96185868 11.78816332  3.95256551  8.76758378  8.05792121 12.69666278
#  18.24613917  7.01502456  7.36062453 13.04843868]

# %%
## CHECK FOR OVERFITTING

r2_train = regression.score(X_train_scaled,Y_train)
r2_test = regression.score(X_test_scaled,Y_test)

print(f"R^2 Score on Training Data: {r2_train}")
print(f"R^2 Score on Testing Data: {r2_test}")
# Out:
# R^2 Score on Training Data: 0.8352523092131758
# R^2 Score on Testing Data: 0.7768402025570351
